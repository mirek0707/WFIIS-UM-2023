# %% [markdown]
# # Uwagi o tablicach numpy

# %%
import numpy as np
a=np.array([1,2,3,4,5,6,7])
b=np.array([1,2,3,4,5,6,9])

# %%
(a+b)+2
# Out:
# array([ 4,  6,  8, 10, 12, 14, 18])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (7,)

# %%
a1 = a.reshape(7,1)
a1
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6],
#        [7]])

# %%
a2 = a.reshape(1,7)
a2
# Out:
# array([[1, 2, 3, 4, 5, 6, 7]])

# %%
a*=2

# %%
a
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14])

# %%
a1*3
# Out:
# array([[ 6],
#        [12],
#        [18],
#        [24],
#        [30],
#        [36],
#        [42]])

# %%
a*b
# Out:
# array([  2,   8,  18,  32,  50,  72, 126])

# %%
a*a1
# Out:
# array([[  4,   8,  12,  16,  20,  24,  28],
#        [  8,  16,  24,  32,  40,  48,  56],
#        [ 12,  24,  36,  48,  60,  72,  84],
#        [ 16,  32,  48,  64,  80,  96, 112],
#        [ 20,  40,  60,  80, 100, 120, 140],
#        [ 24,  48,  72,  96, 120, 144, 168],
#        [ 28,  56,  84, 112, 140, 168, 196]])

# %%
a1*a
# Out:
# array([[  4,   8,  12,  16,  20,  24,  28],
#        [  8,  16,  24,  32,  40,  48,  56],
#        [ 12,  24,  36,  48,  60,  72,  84],
#        [ 16,  32,  48,  64,  80,  96, 112],
#        [ 20,  40,  60,  80, 100, 120, 140],
#        [ 24,  48,  72,  96, 120, 144, 168],
#        [ 28,  56,  84, 112, 140, 168, 196]])

# %%
a*a
# Out:
# array([  4,  16,  36,  64, 100, 144, 196])

# %%
np.sin(a)
# Out:
# array([ 0.90929743, -0.7568025 , -0.2794155 ,  0.98935825, -0.54402111,
#        -0.53657292,  0.99060736])

# %% [markdown]
# # Robienie wykresow w matplotlib

# %%
x=np.linspace(-5,5,50)

# %%
x
# Out:
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
y = x**2

# %%
from matplotlib import pyplot as plt
plt.plot(x,y)
plt.plot(x,x**3)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(-2,2)

plt.savefig("wielomiany.png")

plt.savefig("/content/drive/MyDrive/Colab Notebooks/wielomiany.pdf")

# %%
fig, ax = plt.subplots(2,2)
fig.set_size_inches(8,8)
ax[0,0].plot(x,x**2)
ax[0,1].plot(x,x**5)
ax[1,0].plot(x,np.sin(x))
ax[1,1].plot(x,x**6)

# %%
#plt.show jakby sie nie pokazywalo

# %% [markdown]
# #Pandas - podstawowe zagadnienia

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataLHCbweight.txt", sep="\s+", 
                 names=["E", "I", "dI"])
df
# Out:
#           E           I         dI
# 0    4035.0   16.828310   7.565365
# 1    4037.0   74.710500  15.281850
# 2    4039.0  106.694100  17.814950
# 3    4041.0  133.472200  20.513530
# 4    4043.0  161.329000  22.045700
# ..      ...         ...        ...
# 541  5117.0   22.185620   8.959461
# 542  5119.0   24.641330   8.841099
# 543  5121.0   21.404630   8.053610
# 544  5123.0   10.904280   6.296619
# 545  5125.0    3.685502   3.685502
#
# [546 rows x 3 columns]

# %%
df["E"].head
# Out:
# <bound method NDFrame.head of 0      4035.0
# 1      4037.0
# 2      4039.0
# 3      4041.0
# 4      4043.0
#         ...
# 541    5117.0
# 542    5119.0
# 543    5121.0
# 544    5123.0
# 545    5125.0
# Name: E, Length: 546, dtype: float64>

# %%
plt.errorbar(df['E'], df['I'], df['dI'])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
subset=df[(df['E']>4250) & (df['E']<4350)]
plt.errorbar(subset['E'], subset['I'], subset['dI'], fmt=".")
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Cwiczenie 1

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataLHCbweight.txt", sep="\s+", names=["E", "I", "dI"])
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataLHCball.txt", sep="\s+", names=["E", "I", "dI"])
df3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataLHCbkp.txt", sep="\s+", names=["E", "I", "dI"])

subset1=df1[(df['E']>4950) & (df['E']<5050)]
subset2=df2[(df['E']>4950) & (df['E']<5050)]
subset3=df3[(df['E']>4950) & (df['E']<5050)]
fig, ax = plt.subplots(3)
fig.set_size_inches(8,8)
ax[0].errorbar(subset1['E'], subset1['I'], subset1['dI'], fmt=".")
ax[1].errorbar(subset2['E'], subset2['I'], subset2['dI'], fmt=".")
ax[2].errorbar(subset3['E'], subset3['I'], subset3['dI'], fmt=".")
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Regresja liniowa

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score #kwadrat wskaznika korelacji

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# %%
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# %%
# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# # Cwiczenie 2

# %%
index = abs(regr.predict(diabetes_X) - diabetes_y) <= 80
new_X = diabetes_X[index]
new_Y = diabetes_y[index]

print(new_X.shape)
print(new_Y.shape)

train_X = new_X [:-20]
train_Y = new_Y[:-20]
test_X = new_X[-20:]
test_Y = new_Y[-20:]



regr2 = linear_model.LinearRegression()
regr2.fit(train_X, train_Y)

pred_Y = regr2.predict(test_X)

# The coefficients
print("Coefficients: \n", regr2.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(test_Y, pred_Y))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(test_Y, pred_Y))

# Plot outputs
plt.scatter(test_X, test_Y, color="black")
plt.plot(test_X, pred_Y, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# (348, 1)
# (348,)
# Coefficients:
#  [1059.57994683]
# Mean squared error: 1311.28
# Coefficient of determination: 0.73
